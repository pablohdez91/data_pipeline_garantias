# %%
from IPython import get_ipython

import time
start_time_total = time.time()

# %%
get_ipython().run_line_magic("run", "01_pagos_recup.ipynb")

# %%
get_ipython().run_line_magic("run", "02_saldos_totales.ipynb")

# %%
get_ipython().run_line_magic("run", "03_prefoto.ipynb")

# %%
get_ipython().run_line_magic("run", "04_curva_recup.ipynb")

# %%
get_ipython().run_line_magic("run", "05_saldos.ipynb")

# %%
get_ipython().run_line_magic("run", "06_fotos.ipynb")

# %%
end_time_total = time.time()
end_time_total - start_time_total
# Out:
# 160.21915459632874
